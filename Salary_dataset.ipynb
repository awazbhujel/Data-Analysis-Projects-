# %% [markdown]
# **Context**
#
#
# Information Technology in India is a vast industry that comprises information technology services, consulting, and outsourcing. The IT industry accounted for 8% of India's GDP in 2020. The IT and BPM industry's revenue is estimated at US Dollar 194 billion in FY 2021, an increase of 2.3 % YoY. The domestic revenue of the IT industry is estimated at US Dollar 45 billion and export revenue is estimated at US Dollar 150 billion in FY 2021.
#
# The IT-BPM sector overall employs 4.5 million people as of March 2021. The Indian IT-BPM industry has the highest employee attrition rate. In recent years the industry has witnessed skyrocketing resignations cutting across the hierarchy. As a global outsourcing hub, the Indian IT industry is infamous for exploiting cheap labor. As the IT-BPM sector evolves, many are concerned that artificial intelligence (AI) will drive significant automation and destroy jobs in the coming years.
#
# The software industry includes businesses for the development, maintenance, and publication of software that are using different business models, mainly either "license/maintenance based" (on-premises) or "Cloud-based" (such as SaaS, PaaS, IaaS, MBaaS, MSaaS, DCaaS, etc.). The industry also includes software services, such as training, documentation, consulting, and data recovery.
#
# Content
# This Dataset contains information of 22700+ Software Professionals with different features like their Salaries (₹), Name of the Company, Company Rating, Number of times Salaries Reported, and Location of the Company.
#
# Structure of the Dataset Software Professional Salaries - 2022 ├── Rating
#
# ├── Company Name
#
# ├── Job Title
#
# ├── Salary (Indian Rupee - ₹) ├── Salaries Reported
#
# ├── Location
#
# ├── Employment Status
#
# └── Job Roles

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#import the data
from urllib.request import urlretrieve
url = "https://raw.githubusercontent.com/muhammadanas0716/Data-Science-Projects---EDA/main/3.%20Salary%20Dataset%20-%20Analysis/Salary%20Dataset.csv"
netflix_df = pd.read_csv(url)
df = netflix_df.copy()

# %%
df.shape
# Out:
# (22770, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22770 entries, 0 to 22769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             22770 non-null  float64
#  1   Company Name       22770 non-null  object
#  2   Job Title          22770 non-null  object
#  3   Salary             22770 non-null  int64
#  4   Salaries Reported  22770 non-null  int64
#  5   Location           22770 non-null  object
#  6   Employment Status  22770 non-null  object
#  7   Job Roles          22770 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
df.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %%
#descriptive analyis
df.describe()
# Out:
#              Rating        Salary  Salaries Reported
# count  22770.000000  2.277000e+04       22770.000000
# mean       3.918213  6.953872e+05           1.855775
# std        0.519675  8.843990e+05           6.823668
# min        1.000000  2.112000e+03           1.000000
# 25%        3.700000  3.000000e+05           1.000000
# 50%        3.900000  5.000000e+05           1.000000
# 75%        4.200000  9.000000e+05           1.000000
# max        5.000000  9.000000e+07         361.000000

# %% [markdown]
# Eda

# %%
df.columns
# Out:
# Index(['Rating', 'Company Name', 'Job Title', 'Salary', 'Salaries Reported',
#        'Location', 'Employment Status', 'Job Roles'],
#       dtype='object')

# %%
sns.pairplot(df)

# %%
#analysis of Rating columns
df["Rating"].value_counts().sort_values(ascending=False)
# Out:
# 4.00    2895
# 3.90    2473
# 3.80    2471
# 4.10    2111
# 3.70    1479
# 4.20    1323
# 4.30    1294
# 3.60    1009
# 4.40     883
# 4.50     861
# 3.50     801
# 3.30     727
# 5.00     672
# 3.40     574
# 4.60     464
# 4.70     401
# 3.00     333
# 3.10     329
# 3.20     316
# 4.80     283
# 2.90     177
# 4.90     157
# 2.80     129
# 2.70      98
# 2.60      77
# 1.00      67
# 2.50      66
# 2.00      54
# 2.40      53
# 2.30      43
# 2.20      43
# 3.95      27
# 2.10      15
# 1.90      15
# 1.80      12
# 3.85      11
# 1.50       8
# 1.60       8
# 1.40       5
# 1.70       4
# 1.30       2
# Name: Rating, dtype: int64

# %%
df["Rating"].unique()
# Out:
# array([3.8 , 4.5 , 4.  , 4.4 , 4.2 , 3.7 , 3.1 , 3.6 , 3.9 , 4.8 , 4.1 ,
#        4.3 , 4.9 , 5.  , 4.6 , 3.3 , 2.9 , 3.5 , 3.  , 1.  , 3.4 , 2.8 ,
#        4.7 , 3.2 , 2.4 , 2.2 , 2.7 , 1.8 , 2.1 , 2.3 , 2.6 , 2.  , 1.4 ,
#        1.5 , 2.5 , 1.7 , 1.9 , 1.6 , 3.95, 1.3 , 3.85])

# %%
df[df["Rating"]==5].groupby(["Salary","Job Title"]).sum()
# Out:
#                                                         Rating  \
# Salary  Job Title
# 29568   Software Engineer - Java Developer                 5.0
# 52800   Web Developer                                      5.0
# 60000   Android Developer - Intern                         5.0
#         Front End Developer - Intern                       5.0
#         Front-End Developer - Intern                       5.0
# ...                                                        ...
# 3300000 Front End Lead                                     5.0
# 3600000 IOS Team Lead                                      5.0
# 4200000 Sr. Android Developer                              5.0
# 7300000 SQL Server Database Administrator - Contractor     5.0
# 9700000 Software Development Engineer (SDE) II             5.0
#
#                                                         Salaries Reported
# Salary  Job Title
# 29568   Software Engineer - Java Developer                              1
# ...

# %%
sns.histplot(x=df.Salary)

# %%
#company analysis
df["Company Name"].unique()
# Out:
# array(['Sasken', 'Advanced Millennium Technologies', 'Unacademy', ...,
#        'Unicon Systems', 'Expert Solutions', 'Nextgen Innovation Labs'],
#       dtype=object)

# %%
#highest job title available in  market
top10job=df["Job Title"].value_counts().sort_values(ascending=False).head(10)
top10job
# Out:
# Software Development Engineer                   2351
# Android Developer                               2029
# Software Development Engineer (SDE)             1614
# Front End Developer                             1412
# Test Engineer                                   1314
# Web Developer                                    853
# Software Development Engineer - Intern           771
# Software Development Engineer In Test (SDET)     766
# Backend Developer                                534
# Python Developer                                 485
# Name: Job Title, dtype: int64

# %%
#salary
top10salary=df["Salary"].value_counts(ascending=False).head(10)
top10salary
# Out:
# 300000     1783
# 400000     1697
# 500000     1599
# 600000     1381
# 200000     1084
# 700000     1018
# 1000000     963
# 800000      901
# 900000      724
# 100000      603
# Name: Salary, dtype: int64

# %%
df[df["Salary"]==90000000]
# Out:
#        Rating       Company Name                            Job Title  \
# 18635     3.6  Thapar University  Software Development Engineer (SDE)
#
#          Salary  Salaries Reported   Location Employment Status Job Roles
# 18635  90000000                  1  New Delhi         Full Time       SDE

# %%
df["Salary"].value_counts(ascending=False).tail(10)
# Out:
# 2059200    1
# 33792      1
# 1883904    1
# 8700000    1
# 2021184    1
# 580800     1
# 1239744    1
# 63360      1
# 1034880    1
# 2016960    1
# Name: Salary, dtype: int64

# %% [markdown]
# Salary Columns has an outliers..lets remove it

# %%
sns.histplot(df.Salary,kde=True)

# %%
sns.boxplot(df["Salary"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
mean = df.Salary.mean()
std = df.Salary.std()
mean
# Out:
# 695387.2112428634

# %%
max_limit = df.Salary.mean()+ 3*df.Salary.std()
min_limit = df.Salary.mean()- 3*df.Salary.std()
max_limit,min_limit
# Out:
# (3348584.2522714133, -1957809.8297856865)

# %%
q1,q3=df.Salary.quantile([0.25,0.75])
print(q1,q3)
# Out:
# 300000.0 900000.0

# %%
#iqr
iqr = q3-q1
iqr
# Out:
# 600000.0

# %%
lower_bound = q1-(1.5*iqr)
upper_bound  = q3+(1.5*iqr)
print(lower_bound,upper_bound)
# Out:
# -600000.0 1800000.0

# %%
outliers= df[(df["Salary"]<lower_bound) | (df["Salary"]>3348584)]

# %%
df1=df[(df["Salary"]>lower_bound) & (df["Salary"]<upper_bound)]

# %%
df.shape[0]-df1.shape[0]
# Out:
# 1311

# %%
#using Z_score to remove outliers
z_score=(df.Salary - df.Salary.mean())/df.Salary.std()

# %%
df.Salary.min()
# Out:
# 2112

# %%
df[df["Salary"]==2112]
# Out:
#        Rating         Company Name               Job Title  Salary  \
# 22563     2.6  Keeves Technologies  Web Developer - Intern    2112
#
#        Salaries Reported   Location Employment Status Job Roles
# 22563                  1  Bangalore            Intern       Web

# %%
df.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %%
df1.boxplot("Salary")

# %%
df.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %%
import plotly.express as px

# %%
top5salary=df1["Salary"].value_counts().sort_values(ascending=False).head(5)

# %%
company_index =df1["Company Name"].value_counts().sort_values(ascending=False).head(5).index
company_values = df1["Company Name"].value_counts().sort_values(ascending=False).head(5).values

# %%
fig = px.bar(df1,x=company_index,y=company_values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# conclusions:
#
# Tata Consultancy Services gives  more it jobs in India.

# %%
df1["Salaries Reported"].value_counts().sort_values(ascending=False).head()
# Out:
# 1    17158
# 2     2284
# 3      736
# 4      352
# 5      213
# Name: Salaries Reported, dtype: int64

# %%
df1.Location.value_counts().sort_values(ascending=False)
# Out:
# Bangalore         7668
# Hyderabad         4213
# New Delhi         4014
# Chennai           2376
# Pune              2023
# Mumbai             665
# Kolkata            167
# Madhya Pradesh     149
# Kerala             106
# Jaipur              78
# Name: Location, dtype: int64

# %%
df1["Employment Status"].value_counts().sort_values(ascending=False)
# Out:
# Full Time     18814
# Intern         2091
# Contractor      521
# Trainee          33
# Name: Employment Status, dtype: int64

# %%
df1["Job Roles"].unique()
df1["Job Roles"].value_counts().sort_values(ascending=False)
# Out:
# SDE         7485
# Android     2845
# Frontend    2070
# Java        1800
# Testing     1719
# IOS         1551
# Backend     1085
# Web          989
# Python       935
# Database     760
# Mobile       220
# Name: Job Roles, dtype: int64

# %% [markdown]
# Data Visualization

# %%
df1.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
#top 5which it sector is more popular in india?
job_index = df1["Job Title"].value_counts().sort_values(ascending=False).head(5).index
job_value = df1["Job Title"].value_counts().sort_values(ascending=False).head(5).values

# %%
import plotly.graph_objects as go
fig = go.Figure(data=[go.Pie(labels=job_index,values=job_value)])
fig.update_traces(hoverinfo="label+percent",textinfo="value")
fig.update_layout(title="Top 5 Most popuar tech jobs")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# conclusions:
#
# Software Development Engineer has has highest tech jobs in India.

# %%
#which city is popular for tech jobs
location_index = df1["Location"].value_counts().sort_values(ascending=False).head(5).index
location_values = df1["Location"].value_counts().sort_values(ascending=False).head(5).values

fig = go.Figure(data=[go.Pie(labels=location_index,values=location_values)])
fig.update_traces(hoverinfo="label+percent",textinfo="value")
fig.update_layout(title=" Top 5 highest tech city in india")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# conclusions:
#
# Banglore and Hyderabad has the most tech companies in India.

# %%
#which types of job most software devlopers prefer
employment_index=df1["Employment Status"].value_counts().sort_values(ascending=False).index
employment_values = df1["Employment Status"].value_counts().sort_values(ascending=False).values

fig = go.Figure(data=[go.Pie(labels=employment_index,values=employment_values)])
fig.update_traces(hoverinfo="label+percent",textinfo="value")
fig.update_layout(title="Most prefer jobs time")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Conclusions:
#
# 87% people choose Full time

# %%
#which developer  has the most highest paying jobs
job_index=df1["Job Title"].value_counts().sort_values(ascending=False).head(5)
salary= df1["Salary"].head(5).values
fig = px.bar(df1, x=df["Job Title"], y=df["Salary"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df1.sort_values(by="Salary",ascending=False).head(5)
# Out:
#        Rating Company Name                            Job Title   Salary  \
# 4481      4.0           GE        Oracle Database Administrator  1700000
# 4514      4.2          CSG        Oracle Database Administrator  1700000
# 21519     4.7       FreJun                        Test Engineer  1700000
# 859       3.7       BYJU'S              Senior Android Engineer  1700000
# 3209      4.1       Myntra  Backend Software Engineer At Myntra  1700000
#
#        Salaries Reported   Location Employment Status Job Roles
# 4481                   1  Bangalore         Full Time  Database
# 4514                   1  Bangalore         Full Time  Database
# 21519                  1  Bangalore         Full Time   Testing
# 859                    1  Bangalore         Full Time   Android
# 3209                   2  Bangalore         Full Time   Backend

# %%
job_index = df1["Job Title"].value_counts().head(5).index
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Concluions:
#
# 1. Software Development Engineer has more number of people

# %%
#top 10 prefer jobs
df1["Job Roles"].value_counts().head(5)
# Out:
# SDE         7485
# Android     2845
# Frontend    2070
# Java        1800
# Testing     1719
# Name: Job Roles, dtype: int64

# %%
fig = px.bar(data_frame=df1,x="Location",y="Salary",title="City with highest Salary",color="Job Title",orientation="v")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Company which provide highest salary
fig = px.bar(df1,x=df["Company Name"],y=df["Salary"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %%
#compairing job title,job roles with salary
fig = go.Figure()
fig.add_trace(go.Bar(
    x=df1["Job Title"].value_counts().sort_values(ascending=False).head(5).index,
    y=df1["Salary"],
    name='Job Title',
    marker_color='indianred'
))
fig.add_trace(go.Bar(
    x=df1["Job Roles"].value_counts().sort_values(ascending=False).head(5).index,
    y=df1["Salary"],
    name='Job Roles',
    marker_color='lightsalmon'
))
fig.update_layout(barmode='group')
fig.update_layout(title="Comparison of job title,job roles with salary")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Conclusions:
#
# Software Engineer earns more than any other tech jobs
